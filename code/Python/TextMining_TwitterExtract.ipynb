# %%
#importing the required libraries
import os
import time
from ast import literal_eval
from datetime import datetime
import pandas as pd
import snscrape.modules.twitter as sntwitter # the magic
import warnings
warnings.filterwarnings('ignore')

# %%
#setting up the directory
#root_dir = os.path.abspath(os.path.join(os.path.dirname("."), '.'))
#output: /Users/sbp

# %%
#Extractor Module
class ExtractTweets:
    
    def __init__(self, 
                 minTweetCountPerDay=10, 
                 minRetweetCount=0,
                 minLikeCount=0, 
                 minFollowersCount=0, 
                 VerifiedStatus=None, 
                 saveBufferDuration=3600):
        """
        Accepts basic input params each of integer datatype, except for VerifiedStatus which accepts boolean or None.
        """
        self.start_timer = datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S")
        self.min_tweet_count_perDay = minTweetCountPerDay
        self.minRetweetCount = minRetweetCount
        self.minLikeCount = minLikeCount
        self.minFollowersCount = minFollowersCount
        self.VerifiedStatus = VerifiedStatus                           
        self.tweets_df = pd.DataFrame(columns=['date', 'tweet', 'lang', 'retweetCount', 'likeCount', 'replyCount', 
                                               'username', 'user_followersCount','user_friendsCount', 'verifiedStatus', 
                                               'tweet_url', 'hastags', 'chr_count', 'topic'])
        self.save_buffer_duration = saveBufferDuration
        return

    def save_copy(self):
        """
        Saves a temp copy for restoration and prevent API time limit exceed error.
        
        :return:
        pandas dataframe containing twitter record-data.
        """
        data = self.tweets_df.reset_index(drop=True)
        data['date'] = data['date'].apply(lambda x: pd.to_datetime(x).strftime('%Y-%m-%d'))
        for filename in os.listdir("."):
            if filename.endswith('local.csv'):
                os.remove(filename)
        data.to_csv("./save_{}_local.csv".format(data.date.max()), index=False)
        return data
        
    def getTweets(self, start_date, end_date, keywords):
        """
        Extracts historical twitter data.
        
        :params:
        start_date - str in "YYYY-MM-DD" format
        end_date - str in "YYYY-MM-DD" format
        keywords - list of tuples, 
            e.g, [('recession'), ('football, 'worldcup', 'fifa'), ('war', 'ukraine')]
            e.g. ['recession']
        
        :return:
        pandas dataframe with features as:
         date: Tweet Timestamp
         tweet: tweet content
         lang: language classifer used by parent api
         retweetCount: tweet retweeted count
         likeCount: tweet like count
         replyCount: number of replies to original tweet
         username: user who tweeted
         user_followersCount: number of followers user has (tells you how popular the avg tweets are)
         user_friendsCount: number of friends user has
         verifiedStatus: If the user is Verified or not (i.e. pays 8 bucks every month!)
         tweet_url: Link of original tweet (click and see)
         hastags: If any hastags were used (hastags are important for search and info retrieval)
         chr_count: number of english characters in the original tweet
         topic: keywords you used for searching tweets (kind of labels)
        """
        
        if not(isinstance(keywords, list) or isinstance(keywords, tuple)):
            raise Exception("Incorrect Input Format! Please pass a list")
        
        for topic in keywords:
            # for saving local copies every buffer_hour
            st_time = datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S")
            date = pd.to_datetime(start_date, format='%Y-%m-%d')
            e_date = pd.to_datetime(end_date, format='%Y-%m-%d') + pd.to_timedelta(1, unit='d')
            if isinstance(topic, tuple) or isinstance(topic, list):
                topic = " ".join(topic)
            search_query = topic
            print("search_query:", search_query)
        
            while date != e_date:
                nxt_date = date + pd.to_timedelta(1, unit='d')
                content = '{} since:{} until:{} lang:en'.format(search_query, date.strftime('%Y-%m-%d'), nxt_date.strftime('%Y-%m-%d'))
                print(content)
                
                # check for save buffer duration (set to 1 Hr by default)
                delta_buffer = (datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S") - st_time).seconds
                if delta_buffer >= self.save_buffer_duration:
                    self.save_copy()
                    # reset buffer
                    st_time = datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S")

                lst_tweets = []
                for counter, tweet in enumerate(sntwitter.TwitterSearchScraper(content).get_items()):
                    if counter+1 > self.min_tweet_count_perDay: 
                        break
                    if tweet.likeCount >= self.minLikeCount \
                        or tweet.retweetCount >= self.minRetweetCount \
                        or tweet.user.followersCount >= self.minFollowersCount \
                        or (tweet.user.verified and isinstance(tweet.user.verified, bool) and tweet.user.verified == self.VerifiedStatus):
                        
                        # ----------------------------------------------------------------
                        # Potential custom preprocessing module here: 
                        # 1. Simple and short: https://www.kaggle.com/code/zenbird01/pranjalpathak-semantic-clustering-v1-0/notebook
                        # 2. Advanced: ./NLP_basics_preprocessing_vectorization_similarity.ipynb
                        # 3. Best: Check github - https://github.com/pranzell/NLP_Tools
                        # ----------------------------------------------------------------
                        
                        lst_tweets.append([
                            tweet.date, 
                            tweet.content, 
                            tweet.lang,
                            tweet.retweetCount,
                            tweet.likeCount,
                            tweet.replyCount,
                            tweet.user.username, 
                            tweet.user.followersCount, 
                            tweet.user.friendsCount, 
                            tweet.user.verified,
                            tweet.url,
                            tweet.hashtags,
                            len(str(tweet.content).strip()),
                            topic])
                
                self.tweets_df = self.tweets_df.append(pd.DataFrame(lst_tweets, columns=self.tweets_df.columns))
                date = nxt_date
        
        print("\n\nTOTAL TIME TAKEN {} minutes".format(((datetime.strptime(time.strftime("%Y-%m-%d %H:%M:%S"), "%Y-%m-%d %H:%M:%S") - self.start_timer).seconds)/60.0))
        return self.save_copy()
    
    
    def preprocess_shortText(self, text_col):
        # refer to Preprocessing ipynb file
        # https://github.com/pranzell/NLP_Tools
        pass

# %%
#Configuration
minTweetCountPerDay=50
minRetweetCount=100
minLikeCount=100
minFollowersCount=200
VerifiedStatus=None
saveBufferDuration=3600 # in seconds

start_date = "2022-10-01"
end_date = "2023-01-31"

# list of tuples, or a list of single str items check function definition `getTweets()`
keywords = [('supplements'), ("Performance enhancing drugs"), ("proteins"), ("diet")]
#keywords = [('non veganism'), ('antivegan','exvegan','yestomeat','meatlover','antiveganism')]

# %%
#Execution
#keywords = [('non veganism'), ('antivegan','exvegan','yestomeat','meatlover','antiveganism')]

et = ExtractTweets(minTweetCountPerDay, minRetweetCount, minLikeCount, minFollowersCount, VerifiedStatus, saveBufferDuration)
twitter_data = et.getTweets(start_date, end_date, keywords)
# Out:
# search_query: supplements
# supplements since:2022-10-01 until:2022-10-02 lang:en
# supplements since:2022-10-02 until:2022-10-03 lang:en
# supplements since:2022-10-03 until:2022-10-04 lang:en
# supplements since:2022-10-04 until:2022-10-05 lang:en
# supplements since:2022-10-05 until:2022-10-06 lang:en
# supplements since:2022-10-06 until:2022-10-07 lang:en
# supplements since:2022-10-07 until:2022-10-08 lang:en
# supplements since:2022-10-08 until:2022-10-09 lang:en
# supplements since:2022-10-09 until:2022-10-10 lang:en
# supplements since:2022-10-10 until:2022-10-11 lang:en
# supplements since:2022-10-11 until:2022-10-12 lang:en
# supplements since:2022-10-12 until:2022-10-13 lang:en
# supplements since:2022-10-13 until:2022-10-14 lang:en
# supplements since:2022-10-14 until:2022-10-15 lang:en
# supplements since:2022-10-15 until:2022-10-16 lang:en
# supplements since:2022-10-16 until:2022-10-17 lang:en
# supplements since:2022-10-17 until:2022-10-18 lang:en
# supplements since:2022-10-18 until:2022-10-19 lang:en
# supplements since:2022-10-19 until:2022-10-20 lang:en
# supplements since:2022-10-20 until:2022-10-21 lang:en
# supplements since:2022-10-21 until:2022-10-22 lang:en
# supplements since:2022-10-22 until:2022-10-23 lang:en
# supplements since:2022-10-23 until:2022-10-24 lang:en
# supplements since:2022-10-24 until:2022-10-25 lang:en
# supplements since:2022-10-25 until:2022-10-26 lang:en
# supplements since:2022-10-26 until:2022-10-27 lang:en
# supplements since:2022-10-27 until:2022-10-28 lang:en
# supplements since:2022-10-28 until:2022-10-29 lang:en
# supplements since:2022-10-29 until:2022-10-30 lang:en
# supplements since:2022-10-30 until:2022-10-31 lang:en
# supplements since:2022-10-31 until:2022-11-01 lang:en
# supplements since:2022-11-01 until:2022-11-02 lang:en
# supplements since:2022-11-02 until:2022-11-03 lang:en
# supplements since:2022-11-03 until:2022-11-04 lang:en
# supplements since:2022-11-04 until:2022-11-05 lang:en
# supplements since:2022-11-05 until:2022-11-06 lang:en
# supplements since:2022-11-06 until:2022-11-07 lang:en
# supplements since:2022-11-07 until:2022-11-08 lang:en
# supplements since:2022-11-08 until:2022-11-09 lang:en
# supplements since:2022-11-09 until:2022-11-10 lang:en
# supplements since:2022-11-10 until:2022-11-11 lang:en
# supplements since:2022-11-11 until:2022-11-12 lang:en
# supplements since:2022-11-12 until:2022-11-13 lang:en
# supplements since:2022-11-13 until:2022-11-14 lang:en
# supplements since:2022-11-14 until:2022-11-15 lang:en
# supplements since:2022-11-15 until:2022-11-16 lang:en
# supplements since:2022-11-16 until:2022-11-17 lang:en
# supplements since:2022-11-17 until:2022-11-18 lang:en
# supplements since:2022-11-18 until:2022-11-19 lang:en
# supplements since:2022-11-19 until:2022-11-20 lang:en
# supplements since:2022-11-20 until:2022-11-21 lang:en
# supplements since:2022-11-21 until:2022-11-22 lang:en
# supplements since:2022-11-22 until:2022-11-23 lang:en
# supplements since:2022-11-23 until:2022-11-24 lang:en
# supplements since:2022-11-24 until:2022-11-25 lang:en
# supplements since:2022-11-25 until:2022-11-26 lang:en
# supplements since:2022-11-26 until:2022-11-27 lang:en
# supplements since:2022-11-27 until:2022-11-28 lang:en
# supplements since:2022-11-28 until:2022-11-29 lang:en
# supplements since:2022-11-29 until:2022-11-30 lang:en
# supplements since:2022-11-30 until:2022-12-01 lang:en
# supplements since:2022-12-01 until:2022-12-02 lang:en
# supplements since:2022-12-02 until:2022-12-03 lang:en
# supplements since:2022-12-03 until:2022-12-04 lang:en
# supplements since:2022-12-04 until:2022-12-05 lang:en
# supplements since:2022-12-05 until:2022-12-06 lang:en
# supplements since:2022-12-06 until:2022-12-07 lang:en
# supplements since:2022-12-07 until:2022-12-08 lang:en
# supplements since:2022-12-08 until:2022-12-09 lang:en
# supplements since:2022-12-09 until:2022-12-10 lang:en
# supplements since:2022-12-10 until:2022-12-11 lang:en
# supplements since:2022-12-11 until:2022-12-12 lang:en
# supplements since:2022-12-12 until:2022-12-13 lang:en
# supplements since:2022-12-13 until:2022-12-14 lang:en
# supplements since:2022-12-14 until:2022-12-15 lang:en
# supplements since:2022-12-15 until:2022-12-16 lang:en
# supplements since:2022-12-16 until:2022-12-17 lang:en
# supplements since:2022-12-17 until:2022-12-18 lang:en
# supplements since:2022-12-18 until:2022-12-19 lang:en
# supplements since:2022-12-19 until:2022-12-20 lang:en
# supplements since:2022-12-20 until:2022-12-21 lang:en
# supplements since:2022-12-21 until:2022-12-22 lang:en
# supplements since:2022-12-22 until:2022-12-23 lang:en
# supplements since:2022-12-23 until:2022-12-24 lang:en
# supplements since:2022-12-24 until:2022-12-25 lang:en
# supplements since:2022-12-25 until:2022-12-26 lang:en
# supplements since:2022-12-26 until:2022-12-27 lang:en
# supplements since:2022-12-27 until:2022-12-28 lang:en
# supplements since:2022-12-28 until:2022-12-29 lang:en
# supplements since:2022-12-29 until:2022-12-30 lang:en
# supplements since:2022-12-30 until:2022-12-31 lang:en
# supplements since:2022-12-31 until:2023-01-01 lang:en
# supplements since:2023-01-01 until:2023-01-02 lang:en
# supplements since:2023-01-02 until:2023-01-03 lang:en
# supplements since:2023-01-03 until:2023-01-04 lang:en
# supplements since:2023-01-04 until:2023-01-05 lang:en
# supplements since:2023-01-05 until:2023-01-06 lang:en
# supplements since:2023-01-06 until:2023-01-07 lang:en
# supplements since:2023-01-07 until:2023-01-08 lang:en
# supplements since:2023-01-08 until:2023-01-09 lang:en
# supplements since:2023-01-09 until:2023-01-10 lang:en
# supplements since:2023-01-10 until:2023-01-11 lang:en
# supplements since:2023-01-11 until:2023-01-12 lang:en
# supplements since:2023-01-12 until:2023-01-13 lang:en
# supplements since:2023-01-13 until:2023-01-14 lang:en
# supplements since:2023-01-14 until:2023-01-15 lang:en
# supplements since:2023-01-15 until:2023-01-16 lang:en
# supplements since:2023-01-16 until:2023-01-17 lang:en
# supplements since:2023-01-17 until:2023-01-18 lang:en
# supplements since:2023-01-18 until:2023-01-19 lang:en
# supplements since:2023-01-19 until:2023-01-20 lang:en
# supplements since:2023-01-20 until:2023-01-21 lang:en
# supplements since:2023-01-21 until:2023-01-22 lang:en
# supplements since:2023-01-22 until:2023-01-23 lang:en
# supplements since:2023-01-23 until:2023-01-24 lang:en
# supplements since:2023-01-24 until:2023-01-25 lang:en
# supplements since:2023-01-25 until:2023-01-26 lang:en
# supplements since:2023-01-26 until:2023-01-27 lang:en
# supplements since:2023-01-27 until:2023-01-28 lang:en
# supplements since:2023-01-28 until:2023-01-29 lang:en
# supplements since:2023-01-29 until:2023-01-30 lang:en
# supplements since:2023-01-30 until:2023-01-31 lang:en
# supplements since:2023-01-31 until:2023-02-01 lang:en
# search_query: Performance enhancing drugs
# Performance enhancing drugs since:2022-10-01 until:2022-10-02 lang:en
# Performance enhancing drugs since:2022-10-02 until:2022-10-03 lang:en
# Performance enhancing drugs since:2022-10-03 until:2022-10-04 lang:en
# Performance enhancing drugs since:2022-10-04 until:2022-10-05 lang:en
# Performance enhancing drugs since:2022-10-05 until:2022-10-06 lang:en
# Performance enhancing drugs since:2022-10-06 until:2022-10-07 lang:en
# Performance enhancing drugs since:2022-10-07 until:2022-10-08 lang:en
# Performance enhancing drugs since:2022-10-08 until:2022-10-09 lang:en
# Performance enhancing drugs since:2022-10-09 until:2022-10-10 lang:en
# Performance enhancing drugs since:2022-10-10 until:2022-10-11 lang:en
# Performance enhancing drugs since:2022-10-11 until:2022-10-12 lang:en
# Performance enhancing drugs since:2022-10-12 until:2022-10-13 lang:en
# Performance enhancing drugs since:2022-10-13 until:2022-10-14 lang:en
# Performance enhancing drugs since:2022-10-14 until:2022-10-15 lang:en
# Performance enhancing drugs since:2022-10-15 until:2022-10-16 lang:en
# Performance enhancing drugs since:2022-10-16 until:2022-10-17 lang:en
# Performance enhancing drugs since:2022-10-17 until:2022-10-18 lang:en
# Performance enhancing drugs since:2022-10-18 until:2022-10-19 lang:en
# Performance enhancing drugs since:2022-10-19 until:2022-10-20 lang:en
# Performance enhancing drugs since:2022-10-20 until:2022-10-21 lang:en
# Performance enhancing drugs since:2022-10-21 until:2022-10-22 lang:en
# Performance enhancing drugs since:2022-10-22 until:2022-10-23 lang:en
# Performance enhancing drugs since:2022-10-23 until:2022-10-24 lang:en
# Performance enhancing drugs since:2022-10-24 until:2022-10-25 lang:en
# Performance enhancing drugs since:2022-10-25 until:2022-10-26 lang:en
# Performance enhancing drugs since:2022-10-26 until:2022-10-27 lang:en
# Performance enhancing drugs since:2022-10-27 until:2022-10-28 lang:en
# Performance enhancing drugs since:2022-10-28 until:2022-10-29 lang:en
# Performance enhancing drugs since:2022-10-29 until:2022-10-30 lang:en
# Performance enhancing drugs since:2022-10-30 until:2022-10-31 lang:en
# Performance enhancing drugs since:2022-10-31 until:2022-11-01 lang:en
# Performance enhancing drugs since:2022-11-01 until:2022-11-02 lang:en
# Performance enhancing drugs since:2022-11-02 until:2022-11-03 lang:en
# Performance enhancing drugs since:2022-11-03 until:2022-11-04 lang:en
# Performance enhancing drugs since:2022-11-04 until:2022-11-05 lang:en
# Performance enhancing drugs since:2022-11-05 until:2022-11-06 lang:en
# Performance enhancing drugs since:2022-11-06 until:2022-11-07 lang:en
# Performance enhancing drugs since:2022-11-07 until:2022-11-08 lang:en
# Performance enhancing drugs since:2022-11-08 until:2022-11-09 lang:en
# Performance enhancing drugs since:2022-11-09 until:2022-11-10 lang:en
# Performance enhancing drugs since:2022-11-10 until:2022-11-11 lang:en
# Performance enhancing drugs since:2022-11-11 until:2022-11-12 lang:en
# Performance enhancing drugs since:2022-11-12 until:2022-11-13 lang:en
# Performance enhancing drugs since:2022-11-13 until:2022-11-14 lang:en
# Performance enhancing drugs since:2022-11-14 until:2022-11-15 lang:en
# Performance enhancing drugs since:2022-11-15 until:2022-11-16 lang:en
# Performance enhancing drugs since:2022-11-16 until:2022-11-17 lang:en
# Performance enhancing drugs since:2022-11-17 until:2022-11-18 lang:en
# Performance enhancing drugs since:2022-11-18 until:2022-11-19 lang:en
# Performance enhancing drugs since:2022-11-19 until:2022-11-20 lang:en
# Performance enhancing drugs since:2022-11-20 until:2022-11-21 lang:en
# Performance enhancing drugs since:2022-11-21 until:2022-11-22 lang:en
# Performance enhancing drugs since:2022-11-22 until:2022-11-23 lang:en
# Performance enhancing drugs since:2022-11-23 until:2022-11-24 lang:en
# Performance enhancing drugs since:2022-11-24 until:2022-11-25 lang:en
# Performance enhancing drugs since:2022-11-25 until:2022-11-26 lang:en
# Performance enhancing drugs since:2022-11-26 until:2022-11-27 lang:en
# Performance enhancing drugs since:2022-11-27 until:2022-11-28 lang:en
# Performance enhancing drugs since:2022-11-28 until:2022-11-29 lang:en
# Performance enhancing drugs since:2022-11-29 until:2022-11-30 lang:en
# Performance enhancing drugs since:2022-11-30 until:2022-12-01 lang:en
# Performance enhancing drugs since:2022-12-01 until:2022-12-02 lang:en
# Performance enhancing drugs since:2022-12-02 until:2022-12-03 lang:en
# Performance enhancing drugs since:2022-12-03 until:2022-12-04 lang:en
# Performance enhancing drugs since:2022-12-04 until:2022-12-05 lang:en
# Performance enhancing drugs since:2022-12-05 until:2022-12-06 lang:en
# Performance enhancing drugs since:2022-12-06 until:2022-12-07 lang:en
# Performance enhancing drugs since:2022-12-07 until:2022-12-08 lang:en
# Performance enhancing drugs since:2022-12-08 until:2022-12-09 lang:en
# Performance enhancing drugs since:2022-12-09 until:2022-12-10 lang:en
# Performance enhancing drugs since:2022-12-10 until:2022-12-11 lang:en
# Performance enhancing drugs since:2022-12-11 until:2022-12-12 lang:en
# Performance enhancing drugs since:2022-12-12 until:2022-12-13 lang:en
# Performance enhancing drugs since:2022-12-13 until:2022-12-14 lang:en
# Performance enhancing drugs since:2022-12-14 until:2022-12-15 lang:en
# Performance enhancing drugs since:2022-12-15 until:2022-12-16 lang:en
# Performance enhancing drugs since:2022-12-16 until:2022-12-17 lang:en
# Performance enhancing drugs since:2022-12-17 until:2022-12-18 lang:en
# Performance enhancing drugs since:2022-12-18 until:2022-12-19 lang:en
# Performance enhancing drugs since:2022-12-19 until:2022-12-20 lang:en
# Performance enhancing drugs since:2022-12-20 until:2022-12-21 lang:en
# Performance enhancing drugs since:2022-12-21 until:2022-12-22 lang:en
# Performance enhancing drugs since:2022-12-22 until:2022-12-23 lang:en
# Performance enhancing drugs since:2022-12-23 until:2022-12-24 lang:en
# Performance enhancing drugs since:2022-12-24 until:2022-12-25 lang:en
# Performance enhancing drugs since:2022-12-25 until:2022-12-26 lang:en
# Performance enhancing drugs since:2022-12-26 until:2022-12-27 lang:en
# Performance enhancing drugs since:2022-12-27 until:2022-12-28 lang:en
# Performance enhancing drugs since:2022-12-28 until:2022-12-29 lang:en
# Performance enhancing drugs since:2022-12-29 until:2022-12-30 lang:en
# Performance enhancing drugs since:2022-12-30 until:2022-12-31 lang:en
# Performance enhancing drugs since:2022-12-31 until:2023-01-01 lang:en
# Performance enhancing drugs since:2023-01-01 until:2023-01-02 lang:en
# Performance enhancing drugs since:2023-01-02 until:2023-01-03 lang:en
# Performance enhancing drugs since:2023-01-03 until:2023-01-04 lang:en
# Performance enhancing drugs since:2023-01-04 until:2023-01-05 lang:en
# Performance enhancing drugs since:2023-01-05 until:2023-01-06 lang:en
# Performance enhancing drugs since:2023-01-06 until:2023-01-07 lang:en
# Performance enhancing drugs since:2023-01-07 until:2023-01-08 lang:en
# Performance enhancing drugs since:2023-01-08 until:2023-01-09 lang:en
# Performance enhancing drugs since:2023-01-09 until:2023-01-10 lang:en
# Performance enhancing drugs since:2023-01-10 until:2023-01-11 lang:en
# Performance enhancing drugs since:2023-01-11 until:2023-01-12 lang:en
# Performance enhancing drugs since:2023-01-12 until:2023-01-13 lang:en
# Performance enhancing drugs since:2023-01-13 until:2023-01-14 lang:en
# Performance enhancing drugs since:2023-01-14 until:2023-01-15 lang:en
# Performance enhancing drugs since:2023-01-15 until:2023-01-16 lang:en
# Performance enhancing drugs since:2023-01-16 until:2023-01-17 lang:en
# Performance enhancing drugs since:2023-01-17 until:2023-01-18 lang:en
# Performance enhancing drugs since:2023-01-18 until:2023-01-19 lang:en
# Performance enhancing drugs since:2023-01-19 until:2023-01-20 lang:en
# Performance enhancing drugs since:2023-01-20 until:2023-01-21 lang:en
# Performance enhancing drugs since:2023-01-21 until:2023-01-22 lang:en
# Performance enhancing drugs since:2023-01-22 until:2023-01-23 lang:en
# Performance enhancing drugs since:2023-01-23 until:2023-01-24 lang:en
# Performance enhancing drugs since:2023-01-24 until:2023-01-25 lang:en
# Performance enhancing drugs since:2023-01-25 until:2023-01-26 lang:en
# Performance enhancing drugs since:2023-01-26 until:2023-01-27 lang:en
# Performance enhancing drugs since:2023-01-27 until:2023-01-28 lang:en
# Performance enhancing drugs since:2023-01-28 until:2023-01-29 lang:en
# Performance enhancing drugs since:2023-01-29 until:2023-01-30 lang:en
# Performance enhancing drugs since:2023-01-30 until:2023-01-31 lang:en
# Performance enhancing drugs since:2023-01-31 until:2023-02-01 lang:en
# search_query: proteins
# proteins since:2022-10-01 until:2022-10-02 lang:en
# proteins since:2022-10-02 until:2022-10-03 lang:en
# proteins since:2022-10-03 until:2022-10-04 lang:en
# proteins since:2022-10-04 until:2022-10-05 lang:en
# proteins since:2022-10-05 until:2022-10-06 lang:en
# proteins since:2022-10-06 until:2022-10-07 lang:en
# proteins since:2022-10-07 until:2022-10-08 lang:en
# proteins since:2022-10-08 until:2022-10-09 lang:en
# proteins since:2022-10-09 until:2022-10-10 lang:en
# proteins since:2022-10-10 until:2022-10-11 lang:en
# proteins since:2022-10-11 until:2022-10-12 lang:en
# proteins since:2022-10-12 until:2022-10-13 lang:en
# proteins since:2022-10-13 until:2022-10-14 lang:en
# proteins since:2022-10-14 until:2022-10-15 lang:en
# proteins since:2022-10-15 until:2022-10-16 lang:en
# proteins since:2022-10-16 until:2022-10-17 lang:en
# proteins since:2022-10-17 until:2022-10-18 lang:en
# proteins since:2022-10-18 until:2022-10-19 lang:en
# proteins since:2022-10-19 until:2022-10-20 lang:en
# proteins since:2022-10-20 until:2022-10-21 lang:en
# proteins since:2022-10-21 until:2022-10-22 lang:en
# proteins since:2022-10-22 until:2022-10-23 lang:en
# proteins since:2022-10-23 until:2022-10-24 lang:en
# proteins since:2022-10-24 until:2022-10-25 lang:en
# proteins since:2022-10-25 until:2022-10-26 lang:en
# proteins since:2022-10-26 until:2022-10-27 lang:en
# proteins since:2022-10-27 until:2022-10-28 lang:en
# proteins since:2022-10-28 until:2022-10-29 lang:en
# proteins since:2022-10-29 until:2022-10-30 lang:en
# proteins since:2022-10-30 until:2022-10-31 lang:en
# proteins since:2022-10-31 until:2022-11-01 lang:en
# proteins since:2022-11-01 until:2022-11-02 lang:en
# proteins since:2022-11-02 until:2022-11-03 lang:en
# proteins since:2022-11-03 until:2022-11-04 lang:en
# proteins since:2022-11-04 until:2022-11-05 lang:en
# proteins since:2022-11-05 until:2022-11-06 lang:en
# proteins since:2022-11-06 until:2022-11-07 lang:en
# proteins since:2022-11-07 until:2022-11-08 lang:en
# proteins since:2022-11-08 until:2022-11-09 lang:en
# proteins since:2022-11-09 until:2022-11-10 lang:en
# proteins since:2022-11-10 until:2022-11-11 lang:en
# proteins since:2022-11-11 until:2022-11-12 lang:en
# proteins since:2022-11-12 until:2022-11-13 lang:en
# proteins since:2022-11-13 until:2022-11-14 lang:en
# proteins since:2022-11-14 until:2022-11-15 lang:en
# proteins since:2022-11-15 until:2022-11-16 lang:en
# proteins since:2022-11-16 until:2022-11-17 lang:en
# proteins since:2022-11-17 until:2022-11-18 lang:en
# proteins since:2022-11-18 until:2022-11-19 lang:en
# proteins since:2022-11-19 until:2022-11-20 lang:en
# proteins since:2022-11-20 until:2022-11-21 lang:en
# proteins since:2022-11-21 until:2022-11-22 lang:en
# proteins since:2022-11-22 until:2022-11-23 lang:en
# proteins since:2022-11-23 until:2022-11-24 lang:en
# proteins since:2022-11-24 until:2022-11-25 lang:en
# proteins since:2022-11-25 until:2022-11-26 lang:en
# proteins since:2022-11-26 until:2022-11-27 lang:en
# proteins since:2022-11-27 until:2022-11-28 lang:en
# proteins since:2022-11-28 until:2022-11-29 lang:en
# proteins since:2022-11-29 until:2022-11-30 lang:en
# proteins since:2022-11-30 until:2022-12-01 lang:en
# proteins since:2022-12-01 until:2022-12-02 lang:en
# proteins since:2022-12-02 until:2022-12-03 lang:en
# proteins since:2022-12-03 until:2022-12-04 lang:en
# proteins since:2022-12-04 until:2022-12-05 lang:en
# proteins since:2022-12-05 until:2022-12-06 lang:en
# proteins since:2022-12-06 until:2022-12-07 lang:en
# proteins since:2022-12-07 until:2022-12-08 lang:en
# proteins since:2022-12-08 until:2022-12-09 lang:en
# proteins since:2022-12-09 until:2022-12-10 lang:en
# proteins since:2022-12-10 until:2022-12-11 lang:en
# proteins since:2022-12-11 until:2022-12-12 lang:en
# proteins since:2022-12-12 until:2022-12-13 lang:en
# proteins since:2022-12-13 until:2022-12-14 lang:en
# proteins since:2022-12-14 until:2022-12-15 lang:en
# proteins since:2022-12-15 until:2022-12-16 lang:en
# proteins since:2022-12-16 until:2022-12-17 lang:en
# proteins since:2022-12-17 until:2022-12-18 lang:en
# proteins since:2022-12-18 until:2022-12-19 lang:en
# proteins since:2022-12-19 until:2022-12-20 lang:en
# proteins since:2022-12-20 until:2022-12-21 lang:en
# proteins since:2022-12-21 until:2022-12-22 lang:en
# proteins since:2022-12-22 until:2022-12-23 lang:en
# proteins since:2022-12-23 until:2022-12-24 lang:en
# proteins since:2022-12-24 until:2022-12-25 lang:en
# proteins since:2022-12-25 until:2022-12-26 lang:en
# proteins since:2022-12-26 until:2022-12-27 lang:en
# proteins since:2022-12-27 until:2022-12-28 lang:en
# proteins since:2022-12-28 until:2022-12-29 lang:en
# proteins since:2022-12-29 until:2022-12-30 lang:en
# proteins since:2022-12-30 until:2022-12-31 lang:en
# proteins since:2022-12-31 until:2023-01-01 lang:en
# proteins since:2023-01-01 until:2023-01-02 lang:en
# proteins since:2023-01-02 until:2023-01-03 lang:en
# proteins since:2023-01-03 until:2023-01-04 lang:en
# proteins since:2023-01-04 until:2023-01-05 lang:en
# proteins since:2023-01-05 until:2023-01-06 lang:en
# proteins since:2023-01-06 until:2023-01-07 lang:en
# proteins since:2023-01-07 until:2023-01-08 lang:en
# proteins since:2023-01-08 until:2023-01-09 lang:en
# proteins since:2023-01-09 until:2023-01-10 lang:en
# proteins since:2023-01-10 until:2023-01-11 lang:en
# proteins since:2023-01-11 until:2023-01-12 lang:en
# proteins since:2023-01-12 until:2023-01-13 lang:en
# proteins since:2023-01-13 until:2023-01-14 lang:en
# proteins since:2023-01-14 until:2023-01-15 lang:en
# proteins since:2023-01-15 until:2023-01-16 lang:en
# proteins since:2023-01-16 until:2023-01-17 lang:en
# proteins since:2023-01-17 until:2023-01-18 lang:en
# proteins since:2023-01-18 until:2023-01-19 lang:en
# proteins since:2023-01-19 until:2023-01-20 lang:en
# proteins since:2023-01-20 until:2023-01-21 lang:en
# proteins since:2023-01-21 until:2023-01-22 lang:en
# proteins since:2023-01-22 until:2023-01-23 lang:en
# proteins since:2023-01-23 until:2023-01-24 lang:en
# proteins since:2023-01-24 until:2023-01-25 lang:en
# proteins since:2023-01-25 until:2023-01-26 lang:en
# proteins since:2023-01-26 until:2023-01-27 lang:en
# proteins since:2023-01-27 until:2023-01-28 lang:en
# proteins since:2023-01-28 until:2023-01-29 lang:en
# proteins since:2023-01-29 until:2023-01-30 lang:en
# proteins since:2023-01-30 until:2023-01-31 lang:en
# proteins since:2023-01-31 until:2023-02-01 lang:en
# search_query: diet
# diet since:2022-10-01 until:2022-10-02 lang:en
# diet since:2022-10-02 until:2022-10-03 lang:en
# diet since:2022-10-03 until:2022-10-04 lang:en
# diet since:2022-10-04 until:2022-10-05 lang:en
# diet since:2022-10-05 until:2022-10-06 lang:en
# diet since:2022-10-06 until:2022-10-07 lang:en
# diet since:2022-10-07 until:2022-10-08 lang:en
# diet since:2022-10-08 until:2022-10-09 lang:en
# diet since:2022-10-09 until:2022-10-10 lang:en
# diet since:2022-10-10 until:2022-10-11 lang:en
# diet since:2022-10-11 until:2022-10-12 lang:en
# diet since:2022-10-12 until:2022-10-13 lang:en
# diet since:2022-10-13 until:2022-10-14 lang:en
# diet since:2022-10-14 until:2022-10-15 lang:en
# diet since:2022-10-15 until:2022-10-16 lang:en
# diet since:2022-10-16 until:2022-10-17 lang:en
# diet since:2022-10-17 until:2022-10-18 lang:en
# diet since:2022-10-18 until:2022-10-19 lang:en
# diet since:2022-10-19 until:2022-10-20 lang:en
# diet since:2022-10-20 until:2022-10-21 lang:en
# diet since:2022-10-21 until:2022-10-22 lang:en
# diet since:2022-10-22 until:2022-10-23 lang:en
# diet since:2022-10-23 until:2022-10-24 lang:en
# diet since:2022-10-24 until:2022-10-25 lang:en
# diet since:2022-10-25 until:2022-10-26 lang:en
# diet since:2022-10-26 until:2022-10-27 lang:en
# diet since:2022-10-27 until:2022-10-28 lang:en
# diet since:2022-10-28 until:2022-10-29 lang:en
# diet since:2022-10-29 until:2022-10-30 lang:en
# diet since:2022-10-30 until:2022-10-31 lang:en
# diet since:2022-10-31 until:2022-11-01 lang:en
# diet since:2022-11-01 until:2022-11-02 lang:en
# diet since:2022-11-02 until:2022-11-03 lang:en
# diet since:2022-11-03 until:2022-11-04 lang:en
# diet since:2022-11-04 until:2022-11-05 lang:en
# diet since:2022-11-05 until:2022-11-06 lang:en
# diet since:2022-11-06 until:2022-11-07 lang:en
# diet since:2022-11-07 until:2022-11-08 lang:en
# diet since:2022-11-08 until:2022-11-09 lang:en
# diet since:2022-11-09 until:2022-11-10 lang:en
# diet since:2022-11-10 until:2022-11-11 lang:en
# diet since:2022-11-11 until:2022-11-12 lang:en
# diet since:2022-11-12 until:2022-11-13 lang:en
# diet since:2022-11-13 until:2022-11-14 lang:en
# diet since:2022-11-14 until:2022-11-15 lang:en
# diet since:2022-11-15 until:2022-11-16 lang:en
# diet since:2022-11-16 until:2022-11-17 lang:en
# diet since:2022-11-17 until:2022-11-18 lang:en
# diet since:2022-11-18 until:2022-11-19 lang:en
# diet since:2022-11-19 until:2022-11-20 lang:en
# diet since:2022-11-20 until:2022-11-21 lang:en
# diet since:2022-11-21 until:2022-11-22 lang:en
# diet since:2022-11-22 until:2022-11-23 lang:en
# diet since:2022-11-23 until:2022-11-24 lang:en
# diet since:2022-11-24 until:2022-11-25 lang:en
# diet since:2022-11-25 until:2022-11-26 lang:en
# diet since:2022-11-26 until:2022-11-27 lang:en
# diet since:2022-11-27 until:2022-11-28 lang:en
# diet since:2022-11-28 until:2022-11-29 lang:en
# diet since:2022-11-29 until:2022-11-30 lang:en
# diet since:2022-11-30 until:2022-12-01 lang:en
# diet since:2022-12-01 until:2022-12-02 lang:en
# diet since:2022-12-02 until:2022-12-03 lang:en
# diet since:2022-12-03 until:2022-12-04 lang:en
# diet since:2022-12-04 until:2022-12-05 lang:en
# diet since:2022-12-05 until:2022-12-06 lang:en
# diet since:2022-12-06 until:2022-12-07 lang:en
# diet since:2022-12-07 until:2022-12-08 lang:en
# diet since:2022-12-08 until:2022-12-09 lang:en
# diet since:2022-12-09 until:2022-12-10 lang:en
# diet since:2022-12-10 until:2022-12-11 lang:en
# diet since:2022-12-11 until:2022-12-12 lang:en
# diet since:2022-12-12 until:2022-12-13 lang:en
# diet since:2022-12-13 until:2022-12-14 lang:en
# diet since:2022-12-14 until:2022-12-15 lang:en
# diet since:2022-12-15 until:2022-12-16 lang:en
# diet since:2022-12-16 until:2022-12-17 lang:en
# diet since:2022-12-17 until:2022-12-18 lang:en
# diet since:2022-12-18 until:2022-12-19 lang:en
# diet since:2022-12-19 until:2022-12-20 lang:en
# diet since:2022-12-20 until:2022-12-21 lang:en
# diet since:2022-12-21 until:2022-12-22 lang:en
# diet since:2022-12-22 until:2022-12-23 lang:en
# diet since:2022-12-23 until:2022-12-24 lang:en
# diet since:2022-12-24 until:2022-12-25 lang:en
# diet since:2022-12-25 until:2022-12-26 lang:en
# diet since:2022-12-26 until:2022-12-27 lang:en
# diet since:2022-12-27 until:2022-12-28 lang:en
# diet since:2022-12-28 until:2022-12-29 lang:en
# diet since:2022-12-29 until:2022-12-30 lang:en
# diet since:2022-12-30 until:2022-12-31 lang:en
# diet since:2022-12-31 until:2023-01-01 lang:en
# diet since:2023-01-01 until:2023-01-02 lang:en
# diet since:2023-01-02 until:2023-01-03 lang:en
# diet since:2023-01-03 until:2023-01-04 lang:en
# diet since:2023-01-04 until:2023-01-05 lang:en
# diet since:2023-01-05 until:2023-01-06 lang:en
# diet since:2023-01-06 until:2023-01-07 lang:en
# diet since:2023-01-07 until:2023-01-08 lang:en
# diet since:2023-01-08 until:2023-01-09 lang:en
# diet since:2023-01-09 until:2023-01-10 lang:en
# diet since:2023-01-10 until:2023-01-11 lang:en
# diet since:2023-01-11 until:2023-01-12 lang:en
# diet since:2023-01-12 until:2023-01-13 lang:en
# diet since:2023-01-13 until:2023-01-14 lang:en
# diet since:2023-01-14 until:2023-01-15 lang:en
# diet since:2023-01-15 until:2023-01-16 lang:en
# diet since:2023-01-16 until:2023-01-17 lang:en
# diet since:2023-01-17 until:2023-01-18 lang:en
# diet since:2023-01-18 until:2023-01-19 lang:en
# diet since:2023-01-19 until:2023-01-20 lang:en
# diet since:2023-01-20 until:2023-01-21 lang:en
# diet since:2023-01-21 until:2023-01-22 lang:en
# diet since:2023-01-22 until:2023-01-23 lang:en
# diet since:2023-01-23 until:2023-01-24 lang:en
# diet since:2023-01-24 until:2023-01-25 lang:en
# diet since:2023-01-25 until:2023-01-26 lang:en
# diet since:2023-01-26 until:2023-01-27 lang:en
# diet since:2023-01-27 until:2023-01-28 lang:en
# diet since:2023-01-28 until:2023-01-29 lang:en
# diet since:2023-01-29 until:2023-01-30 lang:en
# diet since:2023-01-30 until:2023-01-31 lang:en
# diet since:2023-01-31 until:2023-02-01 lang:en
#
#
# TOTAL TIME TAKEN 28.716666666666665 minutes

# %%
print(twitter_data.shape)
twitter_data.head(3)
# Out:
# (13232, 14)
#          date                                              tweet lang  \
# 0  2022-10-01  tongkat ali + mushroom blend + green blend + g...   en
# 1  2022-10-01  @meatguyf @Ren_Chandler4 I also bought the Fre...   en
# 2  2022-10-01  @danluu No history of doping/supplements in re...   en
#
#   retweetCount likeCount replyCount    username user_followersCount  \
# 0            0         0          0   WhoIsNo17                 593
# 1            0         1          1    Elpico72                 253
# 2            0         1          2  jaseemabid                3863
#
#   user_friendsCount verifiedStatus  \
# 0               377          False
# 1              4934          False
# 2              2473          False
#
#                                            tweet_url hastags chr_count  \
# 0  https://twitter.com/WhoIsNo17/status/157636119...    None       105
# 1  https://twitter.com/Elpico72/status/1576359757...    None       254
# 2  https://twitter.com/jaseemabid/status/15763596...    None       124
#
#          topic
# 0  supplements
# 1  supplements
# 2  supplements

# %%
twitter_data.to_csv('/Users/sbp/Downloads/twitterdatav1.csv', index=False)

# %%
def read_copy(path=""):
    for f in os.listdir(path):
        if f.endswith('local.csv'):
            df = pd.read_csv(f, lineterminator='\n')
            df.hastags = df.hastags.apply(lambda x: literal_eval(x) if str(x) not in ['none', 'nan', 'np.nan', 'null', ''] else None)
            return df
